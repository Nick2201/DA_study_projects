# %%
import pandas as pd

# %%
# https://minfin.gov.ru/ru/document?id_4=80042-kratkaya_ezhemesyachnaya_informatsiya_ob_ispolnenii_federalnogo_byudzheta_mlrd._rub._nakopleno_s_nachala_goda
data_input= pd.read_excel(r'D:\4. Programming\ProjectsSoftware\DA_study_projects\da_study\rf_budget\Prilozhenie_3_dannye_109-111_—_mes.xlsx')
data_input.head(5)
# Out:
#   Unnamed: 0                                     Приложение 3.3           Unnamed: 2           Unnamed: 3           Unnamed: 4           Unnamed: 5           Unnamed: 6           Unnamed: 7           Unnamed: 8           Unnamed: 9          Unnamed: 10          Unnamed: 11          Unnamed: 12          Unnamed: 13          Unnamed: 14          Unnamed: 15          Unnamed: 16          Unnamed: 17          Unnamed: 18          Unnamed: 19          Unnamed: 20          Unnamed: 21          Unnamed: 22          Unnamed: 23          Unnamed: 24          Unnamed: 25          Unnamed: 26          Unnamed: 27          Unnamed: 28          Unnamed: 29          Unnamed: 30          Unnamed: 31          Unnamed: 32          Unnamed: 33          Unnamed: 34          Unnamed: 35          Unnamed: 36          Unnamed: 37          Unnamed: 38          Unnamed: 39          Unnamed: 40          Unnamed: 41          Unnamed: 42          Unnamed: 43          Unnamed: 44          Unnamed: 45
# ...

# %%
data_input = data_input.T
data_input = data_input.reset_index(drop=True)
first_ = data_input.drop(axis=1,columns=[0])


# data_input = data_input.drop(axis=0,index=0)
# data_input.columns = data_input.iloc['РАЗДЕЛ I']
# first_
# data_input.drop(axis=1,columns=['Unnamed: 0'])
# data_input.head()

# %%
categories = first_.loc[0:1,:]
categories
# Out:
#          1              2                    3                      4
# 0       NaN              1                 1.1.                   1.2.  \
# 1  РАЗДЕЛ I  Доходы, всего  Нефтегазовые доходы  Ненефтегазовые доходы
#
#                                      5                 6         7
# 0                                1.2.1.          1.2.1.1.  1.2.1.2.  \
# 1  Связанные с внутренним производством  НДС (внутренний)    Акцизы
#
#                  8                                9                     10
# 0          1.2.1.3.                         1.2.1.4.                1.2.2.  \
# 1  Налог на прибыль  Налог на доходы физических лиц   Связанные с импортом
#
#    ...                                                 44                45
# 0  ...                                             4.1.4.            4.1.5.  \
# 1  ...  Поступления от продажи акций и земельных участ...  Курсовая разница
#
#                               46      47
# ...

# %%
some_df = first_.loc[0,:]

# %%
first_.columns = some_df
first_ = first_.iloc[:, :-1].drop(axis=0,index=[0,1]).rename(columns={first_.columns[0]:'date'})

# %%
# first_.date = first_.date.apply(pd.to_datetime)
# 
budg = 86_262_000_000
mean_pens= 19_435
periods =12
people= 41_775_000
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
first_.loc[[146,147,150],:]
# Out:
# 0          date            1         1.1.         1.2.       1.2.1.     1.2.1.1.    1.2.1.2.    1.2.1.3.   1.2.1.4.       1.2.2.      1.2.2.1   1.2.2.2.    1.2.2.3.      1.2.3. date             2 2.1. 2.2. 2.3. 2.4. 2.5. 2.6. 2.7. 2.8. 2.9. 2.10. 2.11. 2.12. 2.13. 2.14. date            3         3.1. date            4         4.1.       4.1.1.      4.1.2.    4.1.2.1.    4.1.2.2. 4.1.3. 4.1.3.1. 4.1.3.2.    4.1.4.      4.1.5.       4.1.6.       4.1.7.      4.2. 4.2.1. 4.2.2.    4.2.3. date
# 146  янв.23 ***  1357.005667   425.515595   931.490072    443.04867   379.471533  133.665896   -71.87036   1.781601    352.21706   282.296256  10.667928   59.252876  136.224343  NaN   3006.330687  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  -1649.32502 -2074.840615  NaN   1649.32502  1655.842821  3094.076605   -8.088063  173.345063 -181.433125      0        0        0  0.162143  239.517373 -1438.233784  2862.485152 -5.652512      0      0 -5.652512  NaN
# ...

# %%
import re
len(data.columns)

# data.drop(axis=1,columns='РАЗДЕЛ I').shape
data_input = data.T
# data_raw['year'] = data_raw.index.str
# data_raw.index.apply(lambda x: re.search('\d\d',x.str)[0],x)
data_input['header_col']  = data_raw.index
data_raw
# data_raw['year']    =data_raw['header_col'].apply(lambda x: re.match('\d\d',x)[0])
# data_raw.year
